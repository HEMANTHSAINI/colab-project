# %% [markdown]
# <a href="https://colab.research.google.com/github/HEMANTHSAINI/colab-project/blob/MASTER/clusting_133.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d9c0036b-2b51-446a-ba44-3e8d2abdd662" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d9c0036b-2b51-446a-ba44-3e8d2abdd662">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving final.csv to final.csv

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("final.csv")
df.head()
# Out:
#    Unnamed: 0       Star Name  ...         Radius     Gravity
# 0           0             Sun  ...    695700000.0  274.269161
# 1           1          Sirius  ...   1189647000.0  196.971800
# 2           2         Canopus  ...  49394700000.0    0.816115
# 3           3  Alpha Centauri  ...    834840000.0  209.511165
# 4           4        Arcturus  ...  18088200000.0    0.446296
#
# [5 rows x 6 columns]

# %%
X=df.iloc[:,[3,4]].values
wcss = []
for i in range(1, 11):
  kmeans = KMeans(n_clusters=i,init='k-means++', random_state=42)
  kmeans.fit(X)
  wcss.append((kmeans.inertia_))

plt.plot(range(1,11),wcss)
plt.title("Elbow Method")
plt.xlabel('Number of clusters')
plt.show()

# %%
print(X)
# Out:
# [['1.989e+30' '695700000.0']
#  ['4.1769e+30' '1189647000.0']
#  ['2.9835e+31' '49394700000.0']
#  ['2.1879e+30' '834840000.0']
#  ['2.1879e+30' '18088200000.0']
#  ['4.3758e+30' '1878390000.0000002']
#  ['5.1714e+30' '8348400000.0']
#  ['4.574699999999999e+31' '54890730000.00001']
#  ['2.9835e+30' '1321830000.0']
#  ['3.978e+31' '660915000000.0']
#  ['1.33263e+31' '6470010000.000001']
#  ['2.08845e+31' '5983020000.0']
#  ['3.5802e+30' '1252260000.0']
#  ['3.5801999999999996e+31' '6191730000.0']
#  ['2.9835e+30' '30610800000.0']
#  ['2.3868e+31' '473076000000.0']
#  ['2.2734269999999998e+31' '5196879000.0']
#  ['3.7790999999999997e+30' '6122160000.000001']
#  ['3.7790999999999997e+30' '1252260000.0']
#  ['3.7791e+31' '141227100000.0']
#  ['3.1824e+31' '5843880000.0']
#  ['7.558199999999999e+30' '2156670000.0']
#  ['2.48625e+31' '9739800000.0']
#  ['2.88405e+31' '6122160000.000001']
#  ['5.5692e+30' '1669680000.0']
#  ['2.9835e+30' '58438800000.0']
# ...
