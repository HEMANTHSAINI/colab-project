# %% [markdown]
# <a href="https://colab.research.google.com/github/HEMANTHSAINI/colab-project/blob/MASTER/pro.134.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f8d42f96-acd3-4492-8891-907d5f1a33a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f8d42f96-acd3-4492-8891-907d5f1a33a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving final.csv to final (2).csv
# ...

# %%
 rows = []

# reading the file
with open("final.csv","r") as f:
  csvreader = csv.reader(f)
  
  for row in csvreader:
    rows.append(row)

# getting the rows
headers = rows[0]
stars_data_rows = rows[1:]

stars_data_rows[1:3]
# Out:
# [['1', 'Sirius', '0008.6', '4.1769e+30', '1189647000.0', '196.971799550325'],
#  ['2', 'Canopus', '0310', '2.9835e+31', '49394700000.0', '0.8161153386021839']]

# %%
import plotly.express as px
import csv

fig = px.scatter(df, x=["Distance"], y=["Gravity"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0fb203d7-73b8-4aa2-b5fe-ff7fdfb515cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0fb203d7-73b8-4aa2-b5fe-ff7fdfb515cb")) {
#                     Plotly.newPlot(
#                         '0fb203d7-73b8-4aa2-b5fe-ff7fdfb515cb',
# ...

# %%
good_gravity_stars = []

for i in stars_data_rows:
  if float(i[2]) >= 100:
    good_gravity_stars.append(i)

len(good_gravity_stars)

# %%
ideal_stars = []

for i in good_gravity_stars:
  if float(i[5]) < 1.5:
    ideal_stars.append(i)

len(ideal_stars)
# Out:
# 2

# %%
temp = []

for i in ideal_stars:
  if float(i[5]) < 3.5:
    temp.append(i)

len(temp)
# Out:
# 2

# %%
df = pd.DataFrame(ideal_stars)
df.to_csv("data.csv")

# %%
df.head()

fig = px.line(x=df[2] , y=df[3])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6da03e99-4305-4d22-9103-c0855174a5af" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6da03e99-4305-4d22-9103-c0855174a5af")) {
#                     Plotly.newPlot(
#                         '6da03e99-4305-4d22-9103-c0855174a5af',
# ...
